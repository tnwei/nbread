# %% [markdown]
# # Comprehensive Test Notebook
#
# This notebook tests all the different rendering capabilities of nbread.
#
# ## Features tested:
# - **Bold text** and *italic text*
# - `inline code`
# - Lists and links
# - Code blocks in markdown
# - Various output types
# - Errors and tracebacks

# %% [markdown]
# ## Markdown Features
#
# ### Lists
#
# Unordered:
# - Item 1
# - Item 2
#   - Nested item
#   - Another nested
#
# Ordered:
# 1. First
# 2. Second
# 3. Third
#
# ### Code block in markdown
#
# ```python
# def hello():
#     print("This is code in markdown")
#     return 42
# ```
#
# ### Links
#
# [GitHub](https://github.com) and https://example.com

# %%
# Simple print output
print("Hello from nbread test!")
print("Testing print output")
# Out:
# Hello from nbread test!
# Testing print output

# %%
# Execute result (return value)
x = 40 + 2
x
# Out:
# 42

# %%
# List output
fruits = ['apple', 'banana', 'cherry', 'date', 'elderberry']
fruits
# Out:
# ['apple', 'banana', 'cherry', 'date', 'elderberry']

# %%
# Long line and multi-line output
print("This is a very long line of text that should test word wrapping behavior in the terminal when rendered by nbread to make sure everything displays correctly without breaking the layout or causing horizontal scrolling issues")
print("\nMulti-line output:")
for i in range(1, 6):
    print(f"Line {i}")
# Out:
# This is a very long line of text that should test word wrapping behavior in the terminal when rendered by nbread to make sure everything displays correctly without breaking the layout or causing horizontal scrolling issues
#
# Multi-line output:
# Line 1
# Line 2
# Line 3
# Line 4
# Line 5

# %%
# Error traceback test
raise ValueError("This is an intentional test error!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-abc123> in <module>
#       1 # Error traceback test
# ----> 2 raise ValueError("This is an intentional test error!")
#
# ValueError: This is an intentional test error!

# %%
# Unexecuted cell (execution_count is null)
# This cell was never run
print("This won't show in output")

# %%
# Unicode and special characters
print("Testing unicode: ♠ ♣ ♥ ♦")
print("Emoji test: 🐍 🚀 ✨ 🎉")
print("Special chars: © ® ™ € £ ¥")
print("Math symbols: α β γ δ ∞ ∑ ∫")
# Out:
# Testing unicode: ♠ ♣ ♥ ♦
# Emoji test: 🐍 🚀 ✨ 🎉
# Special chars: © ® ™ € £ ¥
# Math symbols: α β γ δ ∞ ∑ ∫

# %%
# Code with various Python syntax
code_sample = '''def example_function(x, y):
    """This is a docstring."""
    result = x + y
    if result > 10:
        return result * 2
    else:
        return result

# Testing indentation and syntax highlighting
for i in range(3):
    print(f"Iteration {i}")
'''
print(code_sample)
# Out:
# def example_function(x, y):
#     """This is a docstring."""
#     result = x + y
#     if result > 10:
#         return result * 2
#     else:
#         return result
#
# # Testing indentation and syntax highlighting
# for i in range(3):
#     print(f"Iteration {i}")

# %%
# LaTeX output test
from IPython.display import display, Latex
display(Latex(r"""\begin{align}
x &= 1 \\
y &= 2
\end{align}"""))
# Out:
# \begin{align}
# x &= 1 \\
# y &= 2
# \end{align}

# %%
# JSON output test
from IPython.display import display, JSON
data = {
    "metadata": {"version": "1.0", "timestamp": "2024-01-01T00:00:00Z"},
    "data": [{"id": 1, "value": 100.5, "active": True}, {"id": 2, "value": 200.75, "active": False}],
    "summary": {"total": 2, "average": 150.625}
}
display(JSON(data))

# %% [markdown]
# ## Edge Cases
#
# Below are some edge cases to test rendering.

# %%
# Cell with no output
silent_variable = "This doesn't print"

# %%
# Cell with only whitespace output
print()

# %%
# Complex data structure
complex_data = {
    'key1': 'value1',
    'key2': [1, 2, 3, 4, 5],
    'key3': {'nested': 'dict', 'with': 'values'},
    'key4': True,
    'key5': None
}
complex_data
# Out:
# {'key1': 'value1',
#  'key2': [1, 2, 3, 4, 5],
#  'key3': {'nested': 'dict', 'with': 'values'},
#  'key4': True,
#  'key5': None}

# %% [markdown]
# ## End of Test Notebook
#
# If you can see this, all cells rendered successfully! 🎉
